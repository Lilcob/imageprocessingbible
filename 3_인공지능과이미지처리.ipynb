# %% [markdown]
# ## 인공신경망 기초

# %% [markdown]
# ### AND, OR, XOR 연산

# %% [markdown]
# #### 데이터 세트 생성

# %%
import tensorflow as tf

x1 = [0,0,1,1]
x2 = [0,1,0,1]
x = tf.transpose(tf.constant([x1,x2],dtype=tf.float32))

and_y = tf.constant([0,0,0,1],dtype=tf.float32)
or_y = tf.constant([0,1,1,1],dtype=tf.float32)
xor_y = tf.constant([0,1,1,0],dtype=tf.float32)

print(f"x: \n{x}")
print(f"AND y:\t{and_y}",f"OR  y:\t{or_y}",f"XOR y:\t{xor_y}",sep="\n")
# Out:
# x:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# AND y:	[0. 0. 0. 1.]
# OR  y:	[0. 1. 1. 1.]
# XOR y:	[0. 1. 1. 0.]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# AND 문제
sns.scatterplot(x=x[:, 0], y=x[:, 1], hue=and_y, ax=axs[0])
axs[0].set_title("AND Problem")
axs[0].set_xlabel("X1")
axs[0].set_ylabel("X2", rotation=0)

# OR 문제
sns.scatterplot(x=x[:, 0], y=x[:, 1], hue=or_y, ax=axs[1])
axs[1].set_title("OR Problem")
axs[1].set_xlabel("X1")
axs[1].set_ylabel("X2", rotation=0)

# XOR 문제
sns.scatterplot(x=x[:, 0], y=x[:, 1], hue=xor_y, ax=axs[2])
axs[2].set_title("XOR Problem")
axs[2].set_xlabel("X1")
axs[2].set_ylabel("X2", rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 퍼셉트론

# %%
# MLP 모델 정의
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(1, input_dim=2, activation='sigmoid')
])

# AND 연산
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1),
              loss='binary_crossentropy',
              metrics=['accuracy'],)

model.fit(x, and_y, epochs=100, batch_size=4)

# 모델 평가
loss, accuracy = model.evaluate(x, and_y)
print(f'Loss: {loss}, Accuracy: {accuracy}')

# 예측
predictions = model.predict(x)
print(f'Predictions:\n{predictions}')
# Out:
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.8923 - accuracy: 0.7500
# Epoch 2/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8412 - accuracy: 0.7500
# Epoch 3/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7969 - accuracy: 0.7500
# Epoch 4/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7581 - accuracy: 0.7500
# Epoch 5/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7233 - accuracy: 0.7500
# Epoch 6/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6919 - accuracy: 0.7500
# Epoch 7/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6630 - accuracy: 0.7500
# Epoch 8/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6365 - accuracy: 0.7500
# Epoch 9/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6120 - accuracy: 0.7500
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5892 - accuracy: 0.7500
# Epoch 11/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5681 - accuracy: 0.7500
# Epoch 12/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5485 - accuracy: 0.7500
# Epoch 13/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5302 - accuracy: 0.7500
# Epoch 14/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5131 - accuracy: 0.7500
# Epoch 15/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4972 - accuracy: 0.7500
# Epoch 16/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4822 - accuracy: 0.7500
# Epoch 17/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4682 - accuracy: 0.7500
# Epoch 18/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4551 - accuracy: 0.7500
# Epoch 19/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4428 - accuracy: 0.7500
# Epoch 20/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4312 - accuracy: 0.7500
# Epoch 21/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4202 - accuracy: 0.7500
# Epoch 22/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4099 - accuracy: 0.7500
# Epoch 23/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4001 - accuracy: 0.7500
# Epoch 24/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.
uracy: 1.0000
# Epoch 100/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1512 - accuracy: 1.0000
# 1/1 [==============================] - 0s 197ms/step - loss: 0.1500 - accuracy: 1.0000
# Loss: 0.1499759554862976, Accuracy: 1.0
# 1/1 [==============================] - 0s 63ms/step
# Predictions:
# [[0.00963795]
#  [0.1558305 ]
#  [0.15544423]
#  [0.77734375]]

# %%
# OR 연산
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(1, input_dim=2, activation='sigmoid')
])

model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x, or_y, epochs=100, batch_size=4)

loss, accuracy = model.evaluate(x, or_y)
print(f'Loss: {loss}, Accuracy: {accuracy}')

predictions = model.predict(x)
print(f'X:\n{x}')
print(f'Predictions:\n{predictions}')
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 328ms/step - loss: 0.5525 - accuracy: 1.0000
# Epoch 2/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4666 - accuracy: 0.7500
# Epoch 3/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4241 - accuracy: 0.7500
# Epoch 4/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3984 - accuracy: 0.7500
# Epoch 5/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3802 - accuracy: 0.7500
# Epoch 6/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3658 - accuracy: 0.7500
# Epoch 7/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3537 - accuracy: 0.7500
# Epoch 8/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3429 - accuracy: 0.7500
# Epoch 9/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3330 - accuracy: 0.7500
# Epoch 10/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3239 - accuracy: 0.7500
# Epoch 11/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3153 - accuracy: 0.7500
# Epoch 12/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3073 - accuracy: 0.7500
# Epoch 13/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2996 - accuracy: 0.7500
# Epoch 14/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2923 - accuracy: 0.7500
# Epoch 15/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2853 - accuracy: 0.7500
# Epoch 16/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2786 - accuracy: 0.7500
# Epoch 17/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2722 - accuracy: 0.7500
# Epoch 18/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2661 - accuracy: 1.0000
# Epoch 19/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2602 - accuracy: 1.0000
# Epoch 20/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2546 - accuracy: 1.0000
# Epoch 21/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2491 - accuracy: 1.0000
# Epoch 22/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2439 - accuracy: 1.0000
# Epoch 23/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2389 - accuracy: 1.0000
# Epoch 24/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2341 - accuracy: 1.0000
# Epoch 25/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2294 - accuracy: 1.0000
# Epoch 26/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2250 - accuracy: 1.0000
# Epoch 27/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2206 - accuracy: 1.0000
# Epoch 28/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2165 - accuracy: 1.0000
# Epoch 29/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2124 - accuracy: 1.0000
# Epoch 30/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2085 - accuracy: 1.0000
# Epoch 31/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2048 - accuracy: 1.0000
# Epoch 32/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2011 - accuracy: 1.0000
# Epoch 33/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1976 - accuracy: 1.0000
# Epoch 34/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1942 - accuracy: 1.0000
# Epoch 35/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1909 - accuracy: 1.0000
# Epoch 36/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1877 - accuracy: 1.0000
# Epoch 37/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1846 - accuracy: 1.0000
# Epoch 38/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1816 - accuracy: 1.0000
# Epoch 39/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1787 - accuracy: 1.0000
# Epoch 40/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1759 - accuracy: 1.0000
# Epoch 41/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1731 - accuracy: 1.0000
# Epoch 42/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1705 - accuracy: 1.0000
# Epoch 43/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1679 - accuracy: 1.0000
# Epoch 44/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1654 - accuracy: 1.0000
# Epoch 45/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1629 - accuracy: 1.0000
# Epoch 46/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1605 - accuracy: 1.0000
# Epoch 47/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1582 - accuracy: 1.0000
# Epoch 48/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1560 - accuracy: 1.0000
# Epoch 49/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1538 - accuracy: 1.0000
# Epoch 50/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1516 - accuracy: 1.0000
# Epoch 51/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1495 - accuracy: 1.0000
# Epoch 52/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1475 - accuracy: 1.0000
# Epoch 53/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1455 - accuracy: 1.0000
# Epoch 54/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1436 - accuracy: 1.0000
# Epoch 55/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1417 - accuracy: 1.0000
# Epoch 56/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1399 - accuracy: 1.0000
# Epoch 57/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1381 - accuracy: 1.0000
# Epoch 58/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1363 - accuracy: 1.0000
# Epoch 59/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1346 - accuracy: 1.0000
# Epoch 60/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1329 - accuracy: 1.0000
# Epoch 61/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1313 - accuracy: 1.0000
# Epoch 62/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1297 - accuracy: 1.0000
# Epoch 63/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1282 - accuracy: 1.0000
# Epoch 64/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1266 - accuracy: 1.0000
# Epoch 65/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1251 - accuracy: 1.0000
# Epoch 66/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1237 - accuracy: 1.0000
# Epoch 67/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1222 - accuracy: 1.0000
# Epoch 68/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1209 - accuracy: 1.0000
# Epoch 69/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1195 - accuracy: 1.0000
# Epoch 70/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1181 - accuracy: 1.0000
# Epoch 71/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1168 - accuracy: 1.0000
# Epoch 72/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1156 - accuracy: 1.0000
# Epoch 73/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1143 - accuracy: 1.0000
# Epoch 74/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1131 - accuracy: 1.0000
# Epoch 75/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1119 - accuracy: 1.0000
# Epoch 76/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1107 - accuracy: 1.0000
# Epoch 77/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1095 - accuracy: 1.0000
# Epoch 78/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1084 - accuracy: 1.0000
# Epoch 79/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1073 - accuracy: 1.0000
# Epoch 80/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1062 - accuracy: 1.0000
# Epoch 81/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1051 - accuracy: 1.0000
# Epoch 82/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1040 - accuracy: 1.0000
# Epoch 83/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1030 - accuracy: 1.0000
# Epoch 84/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1020 - accuracy: 1.0000
# Epoch 85/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1010 - accuracy: 1.0000
# Epoch 86/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1000 - accuracy: 1.0000
# Epoch 87/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0991 - accuracy: 1.0000
# Epoch 88/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0981 - accuracy: 1.0000
# Epoch 89/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0972 - accuracy: 1.0000
# Epoch 90/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0963 - accuracy: 1.0000
# Epoch 91/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0954 - accuracy: 1.0000
# Epoch 92/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0945 - accuracy: 1.0000
# Epoch 93/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0936 - accuracy: 1.0000
# Epoch 94/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0928 - accuracy: 1.0000
# Epoch 95/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0920 - accuracy: 1.0000
# Epoch 96/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0911 - accuracy: 1.0000
# Epoch 97/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0903 - accuracy: 1.0000
# Epoch 98/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0895 - accuracy: 1.0000
# Epoch 99/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0888 - accuracy: 1.0000
# Epoch 100/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0880 - accuracy: 1.0000
# 1/1 [==============================] - 0s 142ms/step - loss: 0.0872 - accuracy: 1.0000
# Loss: 0.0872473195195198, Accuracy: 1.0
# 1/1 [==============================] - 0s 52ms/step
# X:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Predictions:
# [[0.18203393]
#  [0.92973834]
#  [0.9287521 ]
#  [0.99871147]]

# %%
# XOR 연산
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(1, input_dim=2, activation='sigmoid')
])

model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x, xor_y, epochs=100, batch_size=4)

loss, accuracy = model.evaluate(x, xor_y)
print(f'Loss: {loss}, Accuracy: {accuracy}')

predictions = model.predict(x)
print(f'X:\n{x}')
print(f'Predictions:\n{predictions}')
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 324ms/step - loss: 0.7325 - accuracy: 0.5000
# Epoch 2/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7226 - accuracy: 0.5000
# Epoch 3/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7171 - accuracy: 0.5000
# Epoch 4/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7135 - accuracy: 0.5000
# Epoch 5/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7109 - accuracy: 0.5000
# Epoch 6/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7087 - accuracy: 0.5000
# Epoch 7/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7069 - accuracy: 0.5000
# Epoch 8/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7053 - accuracy: 0.5000
# Epoch 9/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7039 - accuracy: 0.5000
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7026 - accuracy: 0.5000
# Epoch 11/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7015 - accuracy: 0.5000
# Epoch 12/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7006 - accuracy: 0.5000
# Epoch 13/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6997 - accuracy: 0.5000
# Epoch 14/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6989 - accuracy: 0.5000
# Epoch 15/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6983 - accuracy: 0.5000
# Epoch 16/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6977 - accuracy: 0.5000
# Epoch 17/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6972 - accuracy: 0.5000
# Epoch 18/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6967 - accuracy: 0.5000
# Epoch 19/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6963 - accuracy: 0.5000
# Epoch 20/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6959 - accuracy: 0.5000
# Epoch 21/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6956 - accuracy: 0.5000
# Epoch 22/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6953 - accuracy: 0.5000
# Epoch 23/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6951 - accuracy: 0.5000
# Epoch 24/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6949 - accuracy: 0.5000
# Epoch 25/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6947 - accuracy: 0.5000
# Epoch 26/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6945 - accuracy: 0.5000
# Epoch 27/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6943 - accuracy: 0.5000
# Epoch 28/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6942 - accuracy: 0.5000
# Epoch 29/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6941 - accuracy: 0.5000
# Epoch 30/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6940 - accuracy: 0.5000
# Epoch 31/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6939 - accuracy: 0.5000
# Epoch 32/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6938 - accuracy: 0.5000
# Epoch 33/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6937 - accuracy: 0.5000
# Epoch 34/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6937 - accuracy: 0.5000
# Epoch 35/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6936 - accuracy: 0.5000
# Epoch 36/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6936 - accuracy: 0.5000
# Epoch 37/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6935 - accuracy: 0.5000
# Epoch 38/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6935 - accuracy: 0.5000
# Epoch 39/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6934 - accuracy: 0.5000
# Epoch 40/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6934 - accuracy: 0.5000
# Epoch 41/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6934 - accuracy: 0.5000
# Epoch 42/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6934 - accuracy: 0.5000
# Epoch 43/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6933 - accuracy: 0.5000
# Epoch 44/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6933 - accuracy: 0.5000
# Epoch 45/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6933 - accuracy: 0.5000
# Epoch 46/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6933 - accuracy: 0.5000
# Epoch 47/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6933 - accuracy: 0.5000
# Epoch 48/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6933 - accuracy: 0.5000
# Epoch 49/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 50/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 51/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 52/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 53/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 54/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 55/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 56/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 57/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 58/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 59/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 60/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 61/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 62/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 63/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 64/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 65/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 66/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 67/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 68/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 69/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 70/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 71/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 72/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 73/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 74/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 75/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 76/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 77/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 78/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 79/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 80/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 81/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 82/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 83/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 84/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 85/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 86/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 87/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 88/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 89/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 90/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 91/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 92/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 93/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 94/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 95/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 96/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 97/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 98/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 99/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 100/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6931 - accuracy: 0.5000
# 1/1 [==============================] - 0s 96ms/step - loss: 0.6931 - accuracy: 0.5000
# Loss: 0.6931477785110474, Accuracy: 0.5
# 1/1 [==============================] - 0s 33ms/step
# X:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Predictions:
# [[0.49915123]
#  [0.4996021 ]
#  [0.50013155]
#  [0.50058234]]

# %% [markdown]
# ##### 다층 퍼셉트론

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(16, input_dim=2, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x, xor_y, epochs=100, batch_size=4)

loss, accuracy = model.evaluate(x, xor_y)
print(f'Loss: {loss}, Accuracy: {accuracy}')

predictions = model.predict(x)
print(f'X:\n{x}')
print(f'Predictions:\n{predictions}')
# Out:
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.8015 - accuracy: 0.7500
# Epoch 2/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7149 - accuracy: 0.7500
# Epoch 3/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6717 - accuracy: 0.5000
# Epoch 4/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6531 - accuracy: 0.5000
# Epoch 5/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6379 - accuracy: 0.7500
# Epoch 6/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6235 - accuracy: 0.7500
# Epoch 7/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6143 - accuracy: 0.7500
# Epoch 8/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5907 - accuracy: 1.0000
# Epoch 9/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5827 - accuracy: 1.0000
# Epoch 10/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5612 - accuracy: 1.0000
# Epoch 11/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5418 - accuracy: 1.0000
# Epoch 12/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5280 - accuracy: 1.0000
# Epoch 13/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4951 - accuracy: 1.0000
# Epoch 14/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4844 - accuracy: 1.0000
# Epoch 15/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4510 - accuracy: 1.0000
# Epoch 16/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4407 - accuracy: 1.0000
# Epoch 17/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4050 - accuracy: 1.0000
# Epoch 18/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3851 - accuracy: 1.0000
# Epoch 19/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3710 - accuracy: 1.0000
# Epoch 20/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3336 - accuracy: 1.0000
# Epoch 21/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3202 - accuracy: 1.0000
# Epoch 22/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2860 - accuracy: 1.0000
# Epoch 23/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2724 - accuracy: 1.0000
# Epoch 24/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2543 - accuracy: 1.0000
# Epoch 25/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2501 - accuracy: 1.0000
# Epoch 26/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2173 - accuracy: 1.0000
# Epoch 27/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2008 - accuracy: 1.0000
# Epoch 28/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1911 - accuracy: 1.0000
# Epoch 29/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1744 - accuracy: 1.0000
# Epoch 30/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1675 - accuracy: 1.0000
# Epoch 31/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1462 - accuracy: 1.0000
# Epoch 32/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1412 - accuracy: 1.0000
# Epoch 33/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1343 - accuracy: 1.0000
# Epoch 34/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1243 - accuracy: 1.0000
# Epoch 35/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1137 - accuracy: 1.0000
# Epoch 36/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1063 - accuracy: 1.0000
# Epoch 37/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1053 - accuracy: 1.0000
# Epoch 38/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0973 - accuracy: 1.0000
# Epoch 39/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0886 - accuracy: 1.0000
# Epoch 40/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0887 - accuracy: 1.0000
# Epoch 41/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0847 - accuracy: 1.0000
# Epoch 42/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0764 - accuracy: 1.0000
# Epoch 43/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0722 - accuracy: 1.0000
# Epoch 44/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0697 - accuracy: 1.0000
# Epoch 45/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0
100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 97/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 98/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 99/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 100/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0144 - accuracy: 1.0000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0141 - accuracy: 1.0000
# Loss: 0.014095804654061794, Accuracy: 1.0
# 1/1 [==============================] - 0s 41ms/step
# X:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Predictions:
# [[0.0253284 ]
#  [0.9895272 ]
#  [0.98903066]
#  [0.00912866]]

# %% [markdown]
# ### 인공지능 모델의 설계 및 학습

# %%
# 임의의 독립 변수 X 값 생성
import tensorflow as tf

x = tf.random.uniform(shape=[100], minval=1, maxval=4)
print(x)
# Out:
# tf.Tensor(
# [2.372521  2.6322994 3.5555437 3.9232826 1.3707356 3.2020717 1.9272035
#  2.8056293 3.2508655 2.6148477 2.3290071 3.668225  3.1298292 3.8164668
#  2.5732732 1.9903063 3.948494  1.7409134 3.1575136 1.9657272 1.4172512
#  3.2862384 3.2121048 3.7830467 2.4342108 2.62668   3.9571376 1.2173076
#  3.8072436 3.4257283 1.3268676 2.7113702 1.7729855 3.1896744 2.18397
#  1.9888589 3.0486076 2.1338902 2.2731686 1.6583604 3.5760632 1.5079092
#  3.5507183 2.1051297 3.5416949 3.329457  1.0422312 2.3018322 2.8777642
#  2.2870836 2.3466642 2.4596138 2.357987  1.7266104 1.4940779 3.3947356
#  3.5460482 1.009387  1.1126056 1.1180876 1.7986578 1.9186337 2.9219928
#  3.750319  2.393104  2.5253365 2.1016612 2.0046072 2.125781  2.598857
#  1.8006408 3.2889335 2.124824  2.6093376 2.0126855 1.1398368 3.505396
#  3.8285067 2.5936513 3.8872151 1.1213095 2.0959463 3.1795537 1.8172855
#  1.0798483 1.0496613 3.5192986 2.4219463 2.2622726 3.745321  1.174977
#  3.8406534 2.90824   3.6569834 2.2526617 1.9518126 2.2392645 2.2504907
#  2.65007   2.5888472], shape=(100,), dtype=float32)

# %%
# 선형 관계가 있는 종속 변수 Y 값 생성
slope = 1.5
intercept = 3
epsilon = tf.random.truncated_normal(shape=[100], mean=0, stddev=0.3)
y = slope * x + intercept + epsilon
print(y)
# Out:
# tf.Tensor(
# [6.74476   7.2772617 8.622717  9.045624  5.0619035 7.6717353 5.905293
#  7.0692835 7.927641  6.5626116 6.4334044 8.029643  7.4742274 8.898156
#  7.0743103 6.148149  9.239174  5.9125695 7.587607  5.934496  4.8628244
#  7.984823  8.3615265 8.64366   7.160224  6.6854777 8.785186  4.4508643
#  8.762458  8.274699  4.8311896 6.848083  5.399192  7.578957  6.071601
#  5.643588  7.671221  6.5394545 6.4848323 5.6152444 8.507325  5.1186233
#  8.29854   6.0420475 7.969048  7.742587  4.909246  6.497458  6.8644843
#  6.462703  5.9278064 6.915589  6.242725  5.6307044 5.248262  7.9113955
#  8.506257  4.5883865 4.7234592 4.823672  5.3222647 5.7683983 7.2177887
#  8.953697  6.5016966 6.7666006 5.982512  6.125962  6.084887  6.548373
#  5.911957  7.6004496 6.289863  6.5255055 5.8243136 4.3064213 8.34051
#  8.774697  6.564211  8.910694  5.0841856 6.5299664 7.724908  5.950401
#  4.4344554 4.18227   8.255539  7.224036  6.1940446 8.848373  4.67861
#  8.803744  7.1300993 8.702858  6.7209067 5.7525964 6.617983  6.2661033
#  6.777974  6.8323107], shape=(100,), dtype=float32)

# %%
# 맷플로립을 사용한 데이터 시각화
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")
plt.scatter(x, y)
plt.xlabel('Feature (X)')
plt.ylabel('Label (Y)')
plt.title('sythetic dataset')
plt.show()

# %% [markdown]
# #### 텐서플로로 선형 데이터 모델링
# ##### 모델 설계

# %%
from tensorflow.keras import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(1, input_shape=(1,)))

# %%
model.compile(loss='mean_squared_error', optimizer='sgd')

# %% [markdown]
# ##### 모델 학습

# %%
x_train = tf.reshape(x, (-1, 1))
x_train.shape
# Out:
# TensorShape([100, 1])

# %%
history = model.fit(x_train, y, epochs=300)
# Out:
# Epoch 1/300
# 4/4 [==============================] - 1s 4ms/step - loss: 40.4873
# Epoch 2/300
# 4/4 [==============================] - 0s 3ms/step - loss: 10.9472
# Epoch 3/300
# 4/4 [==============================] - 0s 3ms/step - loss: 2.9398
# Epoch 4/300
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0637
# Epoch 5/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5991
# Epoch 6/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4857
# Epoch 7/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4495
# Epoch 8/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4368
# Epoch 9/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4346
# Epoch 10/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4215
# Epoch 11/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4153
# Epoch 12/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4106
# Epoch 13/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4019
# Epoch 14/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3980
# Epoch 15/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3923
# Epoch 16/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3872
# Epoch 17/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3844
# Epoch 18/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3841
# Epoch 19/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3741
# Epoch 20/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3728
# Epoch 21/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3654
# Epoch 22/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3610
# Epoch 23/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3558
# Epoch 24/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3518
# Epoch 25/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3487
# Epoch 26/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3443
# Epoch 27/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3412
# Epoch 28/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3365
# Epoch 29/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3335
# Epoch 30/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3280
# Epoch 31/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3266
# Epoch 32/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3226
# Epoch 33/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3198
# Epoch 34/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3144
# Epoch 35/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3114
# Epoch 36/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3098
# Epoch 37/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3052
# Epoch 38/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3005
# Epoch 39/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3004
# Epoch 40/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2948
# Epoch 41/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2914
# Epoch 42/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2902
# Epoch 43/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2903
# Epoch 44/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2817
# Epoch 45/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2785
# Epoch 46/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2784
# Epoch 47/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2736
# Epoch 48/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2715
# Epoch 49/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2665
# Epoch 50/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2638
# Epoch 51/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2622
# Epoch 52/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2591
# Epoch 53/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2566
# Epoch 54/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2534
# Epoch 55/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2503
# Epoch 56/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2469
# Epoch 57/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2448
# Epoch 58/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2423
# Epoch 59/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2390
# Epoch 60/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2363
# Epoch 61/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Reshape
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import mnist
from tqdm import tqdm
from google.colab.patches import cv2_imshow

(train_images, _), (_, _) = mnist.load_data()
train_images = (train_images - 127.5) / 127.5
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
cv2_imshow(train_images[0]*127.5+127.5)
# Out:
# <PIL.Image.Image image mode=L size=28x28>

# %% [markdown]
# #### 모델 생성

# %%
def build_generator(input_dim):
    model = Sequential()
    model.add(Dense(512, input_dim=input_dim, activation='relu'))
    model.add(Dense(28*28, activation='tanh'))
    model.add(Reshape((28, 28)))
    return model

# %%
def build_discriminator():
    model = Sequential()
    model.add(Flatten(input_shape=(28, 28)))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    return model

# %%
INPUT_DIM = 50
BATCH_SIZE = 64
EPOCHS = 10
BUFFER_SIZE = 600

# %%
generator = build_generator(INPUT_DIM)
discriminator = build_discriminator()

generator_optimizer = tf.keras.optimizers.Adam(1e-3)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-2)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(train_images)\
                  .shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# #### 손실 함수

# %%
binary_cross_entropy = tf.keras.losses.BinaryCrossentropy()

def discriminator_loss(real_output, fake_output): # ①
    real_loss = binary_cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = binary_cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return binary_cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
@tf.function
def train_step(images):
    noise = tf.random.normal([BATCH_SIZE, INPUT_DIM])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
      generated_images = generator(noise, training=True)

      real_output = discriminator(images, training=True)
      fake_output = discriminator(generated_images, training=True)

      gen_loss = generator_loss(fake_output)
      disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))
    return gen_loss, disc_loss, generated_images

# %% [markdown]
# #### 모델 학습

# %%
for epoch in range(1,EPOCHS+1):
    t = tqdm(train_dataset)
    for image_batch in t:
        g_loss, d_loss, fake_image = train_step(image_batch)
        t.set_description_str(f"Epoch - {epoch}")
        t.set_postfix({"G_loss":"%0.3f" %g_loss.numpy(),
                       "D_loss":"%0.3f" %d_loss.numpy()})
    cv2_imshow(np.concatenate(
        list(fake_image.numpy()[:10]*127.5+127.5),axis=1))
# Out:
# Epoch - 1: 100%|██████████| 938/938 [00:20<00:00, 45.80it/s, G_loss=17.343, D_loss=0.889]
# <PIL.Image.Image image mode=L size=280x28>
# Epoch - 2: 100%|██████████| 938/938 [00:10<00:00, 89.02it/s, G_loss=53.396, D_loss=2.066]
# <PIL.Image.Image image mode=L size=280x28>
# Epoch - 3: 100%|██████████| 938/938 [00:09<00:00, 101.61it/s, G_loss=1.970, D_loss=0.973]
# <PIL.Image.Image image mode=L size=280x28>
# Epoch - 4: 100%|██████████| 938/938 [00:07<00:00, 129.96it/s, G_loss=3.813, D_loss=0.265]
# <PIL.Image.Image image mode=L size=280x28>
# Epoch - 5: 100%|██████████| 938/938 [00:10<00:00, 91.71it/s, G_loss=7.213, D_loss=1.365]
# <PIL.Image.Image image mode=L size=280x28>
# Epoch - 6: 100%|██████████| 938/938 [00:07<00:00, 128.49it/s, G_loss=3.593, D_loss=0.231]
# <PIL.Image.Image image mode=L size=280x28>
# Epoch - 7: 100%|██████████| 938/938 [00:07<00:00, 124.47it/s, G_loss=2.425, D_loss=0.758]
# <PIL.Image.Image image mode=L size=280x28>
# Epoch - 8: 100%|██████████| 938/938 [00:07<00:00, 129.40it/s, G_loss=7.810, D_loss=1.907]
# <PIL.Image.Image image mode=L size=280x28>
# Epoch - 9: 100%|██████████| 938/938 [00:07<00:00, 133.89it/s, G_loss=3.351, D_loss=0.971]
# <PIL.Image.Image image mode=L size=280x28>
# Epoch - 10: 100%|██████████| 938/938 [00:10<00:00, 91.73it/s, G_loss=1.391, D_loss=1.685]
# <PIL.Image.Image image mode=L size=280x28>

# %% [markdown]
# #### 전체 코드

# %%
# 앞의 코드를 합친 전체 코드
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Reshape
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import mnist
from tqdm import tqdm
from google.colab.patches import cv2_imshow

(train_images, _), (_, _) = mnist.load_data()
train_images = (train_images - 127.5) / 127.5  # 이미지 정규화


train_images[0]


# 생성자 모델 생성
def build_generator(input_dim):
    model = Sequential()
    model.add(Dense(512, input_dim=input_dim, activation='relu'))
    model.add(Dense(28*28, activation='tanh'))
    model.add(Reshape((28, 28)))
    return model

# 판별자 모델 생성
def build_discriminator():
    model = Sequential()
    model.add(Flatten(input_shape=(28, 28)))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    return model

# 하이퍼파라미터 설정
INPUT_DIM = 50
BATCH_SIZE = 64
EPOCHS = 10
BUFFER_SIZE = 600

# 모델 생성
generator = build_generator(INPUT_DIM)
discriminator = build_discriminator()

generator_optimizer = tf.keras.optimizers.Adam(1e-3)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-2)


# 데이터 로더 생성
train_dataset = tf.data.Dataset.from_tensor_slices(train_images).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# 손실함수 정의
binary_cross_entropy = tf.keras.losses.BinaryCrossentropy()

def discriminator_loss(real_output, fake_output):
    real_loss = binary_cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = binary_cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return binary_cross_entropy(tf.ones_like(fake_output), fake_output)


@tf.function
def train_step(images):
    noise = tf.random.normal([BATCH_SIZE, INPUT_DIM])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
      generated_images = generator(noise, training=True)

      real_output = discriminator(images, training=True)
      fake_output = discriminator(generated_images, training=True)

      gen_loss = generator_loss(fake_output)
      disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))
    return gen_loss, disc_loss, generated_images


# 훈련
for epoch in range(1,EPOCHS+1):
    t = tqdm(train_dataset)
    for image_batch in t:
        g_loss, d_loss, fake_image = train_step(image_batch)
        t.set_description_str(f"Epoch - {epoch}")
        t.set_postfix({"G_loss":"%0.3f" %g_loss.numpy(), "D_loss":"%0.3f" %d_loss.numpy()})
    cv2_imshow(np.concatenate(list(fake_image.numpy()[:10]*127.5+127.5),axis=1))


# 생성된 이미지 시각화
import matplotlib.pyplot as plt

examples = 10
dim=(1, examples)
figsize=(10, 1)
noise = np.random.normal(0, 1, (examples, INPUT_DIM))
generated_images = generator.predict(noise)
plt.figure(figsize=figsize)
for i in range(generated_images.shape[0]):
    plt.subplot(dim[0], dim[1], i+1)
    plt.imshow(generated_images[i], interpolation='nearest', cmap='gray_r')
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Epoch - 1: 100%|██████████| 938/938 [00:10<00:00, 89.62it/s, G_loss=3.839, D_loss=0.333]
# <PIL.Image.Image image mode=L size=280x28>
# Epoch - 2: 100%|██████████| 938/938 [00:07<00:00, 132.26it/s, G_loss=14.711, D_loss=0.579]
# <PIL.Image.Image image mode=L size=280x28>
# Epoch - 3: 100%|██████████| 938/938 [00:07<00:00, 130.30it/s, G_loss=10.439, D_loss=3.339]
# <PIL.Image.Image image mode=L size=280x28>
# Epoch - 4: 100%|██████████| 938/938 [00:08<00:00, 114.41it/s, G_loss=8.143, D_loss=0.843]
# <PIL.Image.Image image mode=L size=280x28>
# Epoch - 5: 100%|██████████| 938/938 [00:06<00:00, 134.27it/s, G_loss=5.729, D_loss=0.606]
# <PIL.Image.Image image mode=L size=280x28>
# Epoch - 6: 100%|██████████| 938/938 [00:06<00:00, 148.36it/s, G_loss=8.375, D_loss=2.472]
# <PIL.Image.Image image mode=L size=280x28>
# Epoch - 7: 100%|██████████| 938/938 [00:07<00:00, 121.99it/s, G_loss=3.206, D_loss=0.251]
# <PIL.Image.Image image mode=L size=280x28>
# Epoch - 8: 100%|██████████| 938/938 [00:06<00:00, 150.48it/s, G_loss=3.418, D_loss=1.226]
# <PIL.Image.Image image mode=L size=280x28>
# Epoch - 9: 100%|██████████| 938/938 [00:10<00:00, 91.70it/s, G_loss=4.184, D_loss=0.477]
# <PIL.Image.Image image mode=L size=280x28>
# Epoch - 10: 100%|██████████| 938/938 [00:07<00:00, 128.97it/s, G_loss=2.489, D_loss=0.556]
# <PIL.Image.Image image mode=L size=280x28>
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7808f7b28310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 205ms/step

# %%
# 이미지 생성 예시
cv2_imshow(np.concatenate(list(image_batch.numpy()[:10]*127+127),axis=1))
# Out:
# <PIL.Image.Image image mode=L size=280x28>

# %% [markdown]
# ## 딥러닝을 활용한 이미지 처리
# ### 이미지 분류
# #### 이미지 분류를 위한 데이터 전처리

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
# CIFAR-10 데이터 세트를 불러옵니다.

(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step

# %%
# 데이터를 확인합니다.

print(train_images.shape, train_labels.shape)
print(test_images.shape, test_labels.shape)
# Out:
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %%
# 정규화된 이미지 데이터를 하나 확인합니다.

train_images[0]
# Out:
# array([[[ 59,  62,  63],
#         [ 43,  46,  45],
#         [ 50,  48,  43],
#         ...,
#         [158, 132, 108],
#         [152, 125, 102],
#         [148, 124, 103]],
#
#        [[ 16,  20,  20],
#         [  0,   0,   0],
#         [ 18,   8,   0],
#         ...,
#         [123,  88,  55],
#         [119,  83,  50],
#         [122,  87,  57]],
#
#        [[ 25,  24,  21],
#         [ 16,   7,   0],
#         [ 49,  27,   8],
#         ...,
#         [118,  84,  50],
#         [120,  84,  50],
#         [109,  73,  42]],
#
#        ...,
#
#        [[208, 170,  96],
#         [201, 153,  34],
#         [198, 161,  26],
#         ...,
#         [160, 133,  70],
#         [ 56,  31,   7],
#         [ 53,  34,  20]],
#
#        [[180, 139,  96],
#         [173, 123,  42],
#         [186, 144,  30],
#         ...,
#         [184, 148,  94],
#         [ 97,  62,  34],
#         [ 83,  53,  34]],
#
#        [[177, 144, 116],
#         [168, 129,  94],
#         [179, 142,  87],
#         ...,
#         [216, 184, 140],
#         [151, 118,  84],
#         [123,  92,  72]]], dtype=uint8)

# %%
# 확인을 위해 출력
plt.figure(figsize=(1, 1))
plt.imshow(train_images[32])

# %%
# 정규화를 위해 255로 나누어 줍니다.

train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
train_images[0]
# Out:
# array([[[0.23137255, 0.24313725, 0.24705882],
#         [0.16862745, 0.18039216, 0.17647059],
#         [0.19607843, 0.18823529, 0.16862745],
#         ...,
#         [0.61960784, 0.51764706, 0.42352941],
#         [0.59607843, 0.49019608, 0.4       ],
#         [0.58039216, 0.48627451, 0.40392157]],
#
#        [[0.0627451 , 0.07843137, 0.07843137],
#         [0.        , 0.        , 0.        ],
#         [0.07058824, 0.03137255, 0.        ],
#         ...,
#         [0.48235294, 0.34509804, 0.21568627],
#         [0.46666667, 0.3254902 , 0.19607843],
#         [0.47843137, 0.34117647, 0.22352941]],
#
#        [[0.09803922, 0.09411765, 0.08235294],
#         [0.0627451 , 0.02745098, 0.        ],
#         [0.19215686, 0.10588235, 0.03137255],
#         ...,
#         [0.4627451 , 0.32941176, 0.19607843],
#         [0.47058824, 0.32941176, 0.19607843],
#         [0.42745098, 0.28627451, 0.16470588]],
#
#        ...,
#
#        [[0.81568627, 0.66666667, 0.37647059],
#         [0.78823529, 0.6       , 0.13333333],
#         [0.77647059, 0.63137255, 0.10196078],
#         ...,
#         [0.62745098, 0.52156863, 0.2745098 ],
#         [0.21960784, 0.12156863, 0.02745098],
#         [0.20784314, 0.13333333, 0.07843137]],
#
#        [[0.70588235, 0.54509804, 0.37647059],
#         [0.67843137, 0.48235294, 0.16470588],
#         [0.72941176, 0.56470588, 0.11764706],
#         ...,
#         [0.72156863, 0.58039216, 0.36862745],
#         [0.38039216, 0.24313725, 0.13333333],
#         [0.3254902 , 0.20784314, 0.13333333]],
#
#        [[0.69411765, 0.56470588, 0.45490196],
#         [0.65882353, 0.50588235, 0.36862745],
#         [0.70196078, 0.55686275, 0.34117647],
#         ...,
#         [0.84705882, 0.72156863, 0.54901961],
#         [0.59215686, 0.4627451 , 0.32941176],
#         [0.48235294, 0.36078431, 0.28235294]]])

# %%
# 훈련 데이터셋과 검증 데이터셋으로 나누어 줍니다.

val_images = train_images[45000:]
val_labels = train_labels[45000:]

train_images = train_images[:45000]
train_labels = train_labels[:45000]

# %%
# 모델을 생성합니다.

mlp_model = Sequential([
    Flatten(input_shape=(32, 32, 3)),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# %%
# 모델의 구조를 확인합니다.

mlp_model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 3072)              0
#
#  dense_14 (Dense)            (None, 512)               1573376
#
#  dense_15 (Dense)            (None, 256)               131328
#
#  dense_16 (Dense)            (None, 128)               32896
#
#  dense_17 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 1738890 (6.63 MB)
# Trainable params: 1738890 (6.63 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 모델을 컴파일합니다.

mlp_model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

# %%
# 모델을 훈련합니다.

mlp_model.fit(train_images, train_labels, epochs=5, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/5
# 1403/1407 [============================>.] - ETA: 0s - loss: 1.8775 - accuracy: 0.3172
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x78092051a290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1407/1407 [==============================] - 7s 4ms/step - loss: 1.8773 - accuracy: 0.3173 - val_loss: 1.7234 - val_accuracy: 0.3822
# Epoch 2/5
# 1407/1407 [==============================] - 5s 4ms/step - loss: 1.6989 - accuracy: 0.3896 - val_loss: 1.6493 - val_accuracy: 0.4108
# Epoch 3/5
# 1407/1407 [==============================] - 5s 3ms/step - loss: 1.6135 - accuracy: 0.4183 - val_loss: 1.6456 - val_accuracy: 0.4074
# Epoch 4/5
# 1407/1407 [==============================] - 5s 4ms/step - loss: 1.5549 - accuracy: 0.4421 - val_loss: 1.5453 - val_accuracy: 0.4460
# Epoch 5/5
# 1407/1407 [==============================] - 5s 4ms/step - loss: 1.5132 - accuracy: 0.4587 - val_loss: 1.5482 - val_accuracy: 0.4478

# %%
# 모델을 평가합니다.

mlp_model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.5308 - accuracy: 0.4506
# [1.5308476686477661, 0.4505999982357025]

# %% [markdown]
# #### 합성곱 신경망을 활용한 이미지 분류

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout

# %%
# 모델을 만듭니다.

cnn_model = Sequential([
    Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), padding='same', activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), padding='same', activation='relu'),
    Flatten(),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
    ])

# %%
# 모델의 구조를 확인합니다.

cnn_model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 64)          36928
#
#  flatten_3 (Flatten)         (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_18 (Dense)            (None, 64)                262208
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_19 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 319178 (1.22 MB)
# Trainable params: 319178 (1.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 모델을 컴파일합니다.

cnn_model.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

# %%
# EarlyStopping, ModelCheckpoint 콜백을 정의합니다.

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stopping = EarlyStopping(monitor='val_loss', patience=5)
save_best_only = ModelCheckpoint('best_cifar10_cnn_model.h5', save_best_only=True)

# %%
# 모델을 학습시킵니다.
# 중간에 학습이 중단되는 게 맞습니다.

history = cnn_model.fit(train_images, train_labels, batch_size=512, epochs=100, validation_data=(val_images, val_labels), callbacks=[early_stopping, save_best_only])
# Out:
# Epoch 1/100
# 88/88 [==============================] - 8s 30ms/step - loss: 1.9466 - accuracy: 0.2882 - val_loss: 1.5729 - val_accuracy: 0.4550
# Epoch 2/100
#  9/88 [==>...........................] - ETA: 1s - loss: 1.7048 - accuracy: 0.3770
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 88/88 [==============================] - 1s 17ms/step - loss: 1.6169 - accuracy: 0.4160 - val_loss: 1.3720 - val_accuracy: 0.5104
# Epoch 3/100
# 88/88 [==============================] - 2s 18ms/step - loss: 1.4841 - accuracy: 0.4693 - val_loss: 1.2966 - val_accuracy: 0.5574
# Epoch 4/100
# 88/88 [==============================] - 2s 20ms/step - loss: 1.3859 - accuracy: 0.5045 - val_loss: 1.1925 - val_accuracy: 0.5832
# Epoch 5/100
# 88/88 [==============================] - 2s 18ms/step - loss: 1.3137 - accuracy: 0.5343 - val_loss: 1.1278 - val_accuracy: 0.6120
# Epoch 6/100
# 88/88 [==============================] - 1s 17ms/step - loss: 1.2580 - accuracy: 0.5536 - val_loss: 1.0696 - val_accuracy: 0.6326
# Epoch 7/100
plt.show()

# %%
# 모델을 평가합니다.

cnn_model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7295 - accuracy: 0.7549
# [0.7294793725013733, 0.7548999786376953]

# %%
# 예측 레이블 배열을 생성합니다.

predicted_labels = cnn_model.predict(test_images)
predicted_labels.shape
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7809203eb370> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 313/313 [==============================] - 1s 2ms/step
# (10000, 10)

# %%
# 각 배열의 최대 값의 색인을 뽑아내어 예측 레이블로 사용합니다.

import tensorflow as tf

predicted_labels = tf.argmax(predicted_labels, axis=1)
predicted_labels
# Out:
# <tf.Tensor: shape=(10000,), dtype=int64, numpy=array([3, 8, 8, ..., 5, 1, 7])>

# %%
label_to_name = {
    0: 'airplane', 1: 'automobile', 2: 'bird', 3: 'cat', 4: 'deer',
    5: 'dog', 6: 'frog', 7: 'horse', 8: 'ship', 9: 'truck'
}

# %%
# test_images를 시각화하여 test_labels와 predicted_labels를 비교합니다.
# test_labels와 predicted_labels가 다를 때, xlabel의 색깔을 빨강색으로 변경합니다.

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for i in range(16):
    plt.subplot(4, 4, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(test_images[i], cmap=plt.cm.binary)
    xlabel = f"{label_to_name[int(test_labels[i][0])]} ({label_to_name[int(predicted_labels[i])]})"
    plt.xlabel(xlabel, color='red' if test_labels[i][0] != predicted_labels[i] else 'black')

# %% [markdown]
# ## 객체 인식

# %%
import cv2
import matplotlib.pyplot as plt

# !wget https://raw.githubusercontent.com/Lilcob/test_colab/main/three%20young%20man.jpg

# 이미지 로드
image_path = "/content/three young man.jpg"
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# 하르 캐스케이드 로드
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# 얼굴 탐지
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
print(faces)
# Out:
# --2024-02-26 06:49:36--  https://raw.githubusercontent.com/Lilcob/test_colab/main/three%20young%20man.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 146736 (143K) [image/jpeg]
# Saving to: ‘three young man.jpg’
#
# three young man.jpg 100%[===================>] 143.30K  --.-KB/s    in 0.02s
#
# 2024-02-26 06:49:36 (9.28 MB/s) - ‘three young man.jpg’ saved [146736/146736]
#
# [[449 111 173 173]
#  [721 106 170 170]
#  [159 148 160 160]
#  [371 376 116 116]]

# %%
# 탐지된 얼굴에 사각형 그리기
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (255, 0, 0), 2)

# 결과 표시
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')  # 축 정보 숨기기
plt.show()

# %% [markdown]
# ## 스타일 전이
# ### Tensorflow를 활용한 VAE 모델 실습

# %%
from IPython import display

import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
import time

# %%
# 데이터 세트 준비
(train_images, _), (_, _) = tf.keras.datasets.mnist.load_data()

def preprocess_images(images):
    images = images.reshape((images.shape[0], 28, 28, 1)) / 255.
    return np.where(images > .5, 1.0, 0.0).astype('float32')

train_images = preprocess_images(train_images)

train_shuffle = 60000
batch_size = 128

train_dataset = (tf.data.Dataset.from_tensor_slices(train_images)
                 .shuffle(train_shuffle).batch(batch_size))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step

# %%
# 모델 구현
class VAE(tf.keras.Model):
    """Variational Autoencoder."""

    def __init__(self, latent_dim):
        super(VAE, self).__init__()
        self.latent_dim = latent_dim
        self.encoder = tf.keras.Sequential(
            [
                tf.keras.layers.InputLayer(input_shape=(28, 28, 1)),
                tf.keras.layers.Flatten(),
                tf.keras.layers.Dense(512, activation='relu'),
                tf.keras.layers.Dense(512, activation='relu'),
                # No activation
                tf.keras.layers.Dense(latent_dim + latent_dim),
            ]
        )

        self.decoder = tf.keras.Sequential(
            [
                tf.keras.layers.InputLayer(input_shape=(latent_dim,)),
                tf.keras.layers.Dense(512, activation='relu'),
                tf.keras.layers.Dense(512, activation='relu'),
                # No activation
                tf.keras.layers.Dense(28*28*1),
                tf.keras.layers.Reshape(target_shape=(28, 28, 1)),
            ]
        )

    @tf.function
    def sample(self, eps=None):
        if eps is None:
            eps = tf.random.normal(shape=(100, self.latent_dim))
        return self.decode(eps, apply_sigmoid=True)

    def encode(self, x):
        mean, logvar = tf.split(self.encoder(x), num_or_size_splits=2, axis=1)
        return mean, logvar

    def reparameterize(self, mean, logvar):
        eps = tf.random.normal(shape=mean.shape)
        return eps * tf.exp(logvar * .5) + mean

    def decode(self, z, apply_sigmoid=False):
        logits = self.decoder(z)
        if apply_sigmoid:
            probs = tf.sigmoid(logits)
            return probs
        return logits

# %%
optimizer = tf.keras.optimizers.Adam(4e-4)


def log_normal_pdf(sample, mean, logvar, raxis=1):
    log2pi = tf.math.log(2. * np.pi)
    return tf.reduce_sum(
        -.5 * ((sample - mean) ** 2. * tf.exp(-logvar) + logvar + log2pi),
        axis=raxis)


def compute_loss(model, x):
    mean, logvar = model.encode(x)
    z = model.reparameterize(mean, logvar)
    x_logit = model.decode(z)
    cross_ent = tf.nn.sigmoid_cross_entropy_with_logits(logits=x_logit, labels=x)
    logpx_z = -tf.reduce_sum(cross_ent, axis=[1, 2, 3])
    logpz = log_normal_pdf(z, 0., 0.)
    logqz_x = log_normal_pdf(z, mean, logvar)
    return -tf.reduce_mean(logpx_z + logpz - logqz_x)

@tf.function
def train_step(model, x, optimizer):
    with tf.GradientTape() as tape:
        loss = compute_loss(model, x)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

# %%
# 학습 중간에 확인할 데이터를 정해줍니다.
assert batch_size >= num_examples_to_generate
for test_batch in train_dataset.take(1):
    test_sample = test_batch[0:num_examples_to_generate, :, :, :]

# %%
optimizer = tf.keras.optimizers.Adam(4e-4)


def log_normal_pdf(sample, mean, logvar, raxis=1):
    log2pi = tf.math.log(2. * np.pi)
    return tf.reduce_sum(
        -.5 * ((sample - mean) ** 2. * tf.exp(-logvar) + logvar + log2pi),
        axis=raxis)


def compute_loss(model, x):
    mean, logvar = model.encode(x)
    z = model.reparameterize(mean, logvar)
    x_logit = model.decode(z)
    cross_ent = tf.nn.sigmoid_cross_entropy_with_logits(logits=x_logit, labels=x)
    logpx_z = -tf.reduce_sum(cross_ent, axis=[1, 2, 3])
    logpz = log_normal_pdf(z, 0., 0.)
    logqz_x = log_normal_pdf(z, mean, logvar)
    return -tf.reduce_mean(logpx_z + logpz - logqz_x)

@tf.function
def train_step(model, x, optimizer):
    with tf.GradientTape() as tape:
        loss = compute_loss(model, x)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

# %%
epochs = 50
# 2차원 잠재 백터를 준비합니다.
latent_dim = 2
num_examples_to_generate = 25

# 생성(예측)을 위해 랜덤 벡터를 일정하게 유지하여
# 개선 사항을 더 쉽게 볼 수 있습니다.
random_vector_for_generation = tf.random.normal(
    shape=[num_examples_to_generate, latent_dim])
model = VAE(latent_dim)

# %%
def generate_and_save_images(model, epoch, test_sample):
    mean, logvar = model.encode(test_sample)
    z = model.reparameterize(mean, logvar)
    predictions = model.sample(z)
    fig = plt.figure(figsize=(4, 4))

    for i in range(predictions.shape[0]):
        plt.subplot(5, 5, i + 1)
        plt.imshow(predictions[i, :, :, 0], cmap='gray')
        plt.axis('off')

    plt.savefig('image_at_epoch_{:04d}.png'.format(epoch))
    plt.show()

# %%
generate_and_save_images(model, 0, test_sample)

for epoch in range(1, epochs + 1):
    start_time = time.time()
    for train_x in train_dataset:
        train_step(model, train_x, optimizer)
    end_time = time.time()

    loss = tf.keras.metrics.Mean()
    for test_x in train_dataset:
        loss(compute_loss(model, test_x))
    elbo = -loss.result()
    display.clear_output(wait=False)
    print('Epoch: {}, ELBO: {}, time elapse for current epoch: {}'
          .format(epoch, elbo, end_time - start_time))
    generate_and_save_images(model, epoch, test_sample)
# Out:
# Epoch: 50, ELBO: -130.59060668945312, time elapse for current epoch: 1.6553797721862793

# %%
# 2차원 잠재 공간의 벡터로부터 숫자가 어떻게 생성되는지 확인하기
def plot_latent_images(model, n, digit_size=28):
    """Plots n x n digit images decoded from the latent space."""

    norm = tfp.distributions.Normal(0, 1)
    grid_x = norm.quantile(np.linspace(0.05, 0.95, n))
    grid_y = norm.quantile(np.linspace(0.05, 0.95, n))
    image_width = digit_size*n
    image_height = image_width
    image = np.zeros((image_height, image_width))

    for i, yi in enumerate(grid_x):
        for j, xi in enumerate(grid_y):
            z = np.array([[xi, yi]])
            x_decoded = model.sample(z)
            digit = tf.reshape(x_decoded[0], (digit_size, digit_size))
            image[i * digit_size: (i + 1) * digit_size,
                  j * digit_size: (j + 1) * digit_size] = digit.numpy()

    plt.figure(figsize=(10, 10))
    plt.imshow(image, cmap='Greys_r')
    plt.axis('Off')
    plt.show()

plot_latent_images(model, 20)
